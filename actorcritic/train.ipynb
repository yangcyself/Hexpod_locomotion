# %%
# %matplotlib notebook
from topomain import *
# Out:
# trainUSEGPU: True
# Program started
# Connected to remote API server
# ...
# <img src="data:image/png;base64,..." width="830.7692612416656">
#  State Dimensions :-  1759
#  Action Dimensions :-  6
#  Action Max :-  0.25

# %%
main()
# Out:
# Models loaded succesfully
# last total reward: 0
# EPISODE :-  1
# C:\Users\11657\AppData\Local\Programs\Python\Python36\lib\site-packages\torch\nn\functional.py:995: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# DIFFTARGET: [1.8772072792053223, 0.8588270545005798, -0.37693357467651367]
# DIFFTARGET: [1.681811809539795, 0.6728181838989258, -0.3764205873012543]
# DIFFTARGET: [1.5236374139785767, 0.5040254592895508, -0.37607064843177795]

# %% [markdown]
# # 下面的都是瞎试的

# %%
# %matplotlib notebook
import toyenv as env
import numpy as np
# Out:
# Program started
# Connected to remote API server

# %%
env.reset()
# Out:
# status 0
# [0.5275412797927856,
#  0.30462613701820374,
#  -0.5465241074562073,
#  -2.430769382044673e-05,
#  0.60910964012146,
#  -0.5446318984031677,
#  -0.5275054574012756,
#  0.30448076128959656,
#  -0.5465236902236938,
#  0.5276258587837219,
#  -0.304508775472641,
#  -0.5450348258018494,
#  0.0001437445025658235,
#  -0.6091727018356323,
#  -0.5465070605278015,
#  -0.527411162853241,
#  -0.30464234948158264,
#  -0.5453662872314453,
#  0.0008644952904433012,
#  -0.0012311504688113928,
#  0.5757796764373779,
#  0.0013239821419119835,
#  0.001344245276413858,
#  -6.345518340822309e-05,
#  4.999128341674805,
#  0.0011662349570542574,
#  0.058459341526031494,
#  0]

# %%
act = np.array([0.25]*6)
act[[a for a in range(0,6,2)]] *= -1
env.step(act)
# Out:
# action [[ 0.27753067  0.55463374 -0.54652   ]
#  [-0.77752781  0.5545007  -0.54652   ]
#  [-0.24985504 -0.35917157 -0.54652   ]]
# finished_three_step
# [-0.12688487768173218, 0.12362521141767502, 0.575704038143158] [5.127619743347168, -0.09568192809820175, -0.3271504044532776] 5.336015421489412 5.024964433152006
# -0.3110509883374064
# ([0.4012299180030823,
#   0.43071627616882324,
#   -0.5440125465393066,
#   0.121678426861763,
#   0.4854395091533661,
#   -0.5463503003120422,
#   -0.654321551322937,
#   0.4254003167152405,
#   -0.5438850522041321,
#   0.654321014881134,
#   -0.4253837764263153,
#   -0.546445906162262,
#   -0.12165458500385284,
#   -0.48534151911735535,
#   -0.5438839197158813,
#   -0.4007091522216797,
#   -0.4313228726387024,
#   -0.5464552044868469,
#   -0.12688487768173218,
#   0.12362521141767502,
#   0.575704038143158,
#   0.001953771337866783,
#   0.000498394772876054,
#   -0.005714131519198418,
#   5.127619743347168,
#   -0.09568192809820175,
# ...

# %%
a= np.array([0.40013023200966874,
  0.431903319703215,
  -0.54652,
  0.1222081171998058,
  0.4847687254264481,
  -0.54652,
  -0.6549113986891018,
  0.4259393192519346,
  -0.54652,
  0.6548944198453588,
  -0.4259157100612421,
  -0.54652,
  -0.12219712094939839,
  -0.48480271950625176,
  -0.54652,
  -0.4001242494163337,
  -0.431892934814104,
  -0.54652,
  -0.11293044959274053,
  0.11199599913510694,
  0.54652,
  0.0,
  0.0,
  0.00014382062846048557,
  5.112914289378934,
  -0.11273134284482358,
  0.12348000000000003,
  1])
b = np.array([0.4012299180030823,
  0.43071627616882324,
  -0.5440125465393066,
  0.121678426861763,
  0.4854395091533661,
  -0.5463503003120422,
  -0.654321551322937,
  0.4254003167152405,
  -0.5438850522041321,
  0.654321014881134,
  -0.4253837764263153,
  -0.546445906162262,
  -0.12165458500385284,
  -0.48534151911735535,
  -0.5438839197158813,
  -0.4007091522216797,
  -0.4313228726387024,
  -0.5464552044868469,
  -0.12688487768173218,
  0.12362521141767502,
  0.575704038143158,
  0.001953771337866783,
  0.000498394772876054,
  -0.005714131519198418,
  5.127619743347168,
  -0.09568192809820175,
  -0.3271504044532776,
  1]
)
a-b
# Out:
# array([-1.09968599e-03,  1.18704353e-03, -2.50745346e-03,  5.29690338e-04,
#        -6.70783727e-04, -1.69699688e-04, -5.89847366e-04,  5.39002537e-04,
#        -2.63494780e-03,  5.73404964e-04, -5.31933635e-04, -7.40938377e-05,
#        -5.42535946e-04,  5.38799611e-04, -2.63608028e-03,  5.84902805e-04,
#        -5.70062175e-04, -6.47955132e-05,  1.39544281e-02, -1.16292123e-02,
#        -2.91840381e-02, -1.95377134e-03, -4.98394773e-04,  5.85795215e-03,
#        -1.47054540e-02, -1.70494147e-02,  4.50630404e-01,  0.00000000e+00])

# %%
# %matplotlib notebook
import toyrep as vrep
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f200caa6365d> in <module>()
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
# ----> 2 import toyrep as vrep
#
# ModuleNotFoundError: No module named 'toyrep'

# %%
vrep.ave_ang([3,14,0,-3.14])
# Out:
# -0.6466947345295793
